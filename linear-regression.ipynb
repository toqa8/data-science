# %%
import pandas as pd

df = pd.read_csv(r"D:\toka\depi\2nd ml session\task\train.csv", index_col=0)
pd.set_option("display.max_rows", 5)

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     588 non-null    object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
#  79  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %%
# Check duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
# Selecting only categorical columns
categorical_cols = df.select_dtypes(include=['object', 'category'])

# Get unique values for each categorical column
unique_values_dict = {col: df[col].unique() for col in categorical_cols}

print(unique_values_dict)
# Out:
# {'MSZoning': array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object), 'Street': array(['Pave', 'Grvl'], dtype=object), 'Alley': array([nan, 'Grvl', 'Pave'], dtype=object), 'LotShape': array(['Reg', 'IR1', 'IR2', 'IR3'], dtype=object), 'LandContour': array(['Lvl', 'Bnk', 'Low', 'HLS'], dtype=object), 'Utilities': array(['AllPub', 'NoSeWa'], dtype=object), 'LotConfig': array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object), 'LandSlope': array(['Gtl', 'Mod', 'Sev'], dtype=object), 'Neighborhood': array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object), 'Condition1': array(['Norm', 'Feedr', 'PosN', 'Artery', 'RRAe', 'RRNn', 'RRAn', 'PosA',
#        'RRNe'], dtype=object), 'Condition2': array(['Norm', 'Artery', 'RRNn', 'Feedr', 'PosN', 'PosA', 'RRAn', 'RRAe'],
#       dtype=object), 'BldgType': array(['1Fam', '2fmCon', 'Duplex', 'TwnhsE', 'Twnhs'], dtype=object), 'HouseStyle': array(['2Story', '1Story', '1.5Fin', '1.5Unf', 'SFoyer', 'SLvl', '2.5Unf',
#        '2.5Fin'], dtype=object), 'RoofStyle': array(['Gable', 'Hip', 'Gambrel', 'Mansard', 'Flat', 'Shed'], dtype=object), 'RoofMatl': array(['CompShg', 'WdShngl', 'Metal', 'WdShake', 'Membran', 'Tar&Grv',
#        'Roll', 'ClyTile'], dtype=object), 'Exterior1st': array(['VinylSd', 'MetalSd', 'Wd Sdng', 'HdBoard', 'BrkFace', 'WdShing',
#        'CemntBd', 'Plywood', 'AsbShng', 'Stucco', 'BrkComm', 'AsphShn',
#        'Stone', 'ImStucc', 'CBlock'], dtype=object), 'Exterior2nd': array(['VinylSd', 'MetalSd', 'Wd Shng', 'HdBoard', 'Plywood', 'Wd Sdng',
#        'CmentBd', 'BrkFace', 'Stucco', 'AsbShng', 'Brk Cmn', 'ImStucc',
#        'AsphShn', 'Stone', 'Other', 'CBlock'], dtype=object), 'MasVnrType': array(['BrkFace', nan, 'Stone', 'BrkCmn'], dtype=object), 'ExterQual': array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object), 'ExterCond': array(['TA', 'Gd', 'Fa', 'Po', 'Ex'], dtype=object), 'Foundation': array(['PConc', 'CBlock', 'BrkTil', 'Wood', 'Slab', 'Stone'], dtype=object), 'BsmtQual': array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object), 'BsmtCond': array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object), 'BsmtExposure': array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object), 'BsmtFinType1': array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ'], dtype=object), 'BsmtFinType2': array(['Unf', 'BLQ', nan, 'ALQ', 'Rec', 'LwQ', 'GLQ'], dtype=object), 'Heating': array(['GasA', 'GasW', 'Grav', 'Wall', 'OthW', 'Floor'], dtype=object), 'HeatingQC': array(['Ex', 'Gd', 'TA', 'Fa', 'Po'], dtype=object), 'CentralAir': array(['Y', 'N'], dtype=object), 'Electrical': array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object), 'KitchenQual': array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object), 'Functional': array(['Typ', 'Min1', 'Maj1', 'Min2', 'Mod', 'Maj2', 'Sev'], dtype=object), 'FireplaceQu': array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object), 'GarageType': array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object), 'GarageFinish': array(['RFn', 'Unf', 'Fin', nan], dtype=object), 'GarageQual': array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object), 'GarageCond': array(['TA', 'Fa', nan, 'Gd', 'Po', 'Ex'], dtype=object), 'PavedDrive': array(['Y', 'N', 'P'], dtype=object), 'PoolQC': array([nan, 'Ex', 'Fa', 'Gd'], dtype=object), 'Fence': array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object), 'MiscFeature': array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object), 'SaleType': array(['WD', 'New', 'COD', 'ConLD', 'ConLI', 'CWD', 'ConLw', 'Con', 'Oth'],
#       dtype=object), 'SaleCondition': array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)}

# %%
# show all rows
pd.set_option('display.max_rows', None)
print(df.isnull().sum())
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %%
null_counts = df.isnull().sum()
print(null_counts[null_counts > 0])
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of LotFrontage to see its distribution
sns.histplot(df['LotFrontage'], bins=20, kde=True)
plt.title("Distribution of LotFrontage")
plt.xlabel("LotFrontage")
plt.ylabel("Frequency")
plt.show()

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\3505941688.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LotFrontage'].fillna(df['LotFrontage'].median(), inplace=True)

# %%
df.drop(['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], axis=1, inplace=True)

# %%
df.dropna(subset=['MasVnrArea', 'Electrical'], inplace=True)

# %%
print(df[['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond']].dtypes)
# Out:
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# dtype: object

# %%
# Histogram of GarageYrBlt to see its distribution
sns.histplot(df['GarageYrBlt'], bins=20, kde=True)
plt.title("Distribution of GarageYrBlt")
plt.xlabel("GarageYrBlt")
plt.ylabel("Frequency")
plt.show()

# %%
df['GarageYrBlt'].fillna(df['GarageYrBlt'].median(), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\735951760.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageYrBlt'].fillna(df['GarageYrBlt'].median(), inplace=True)

# %%
df['BsmtQual'].fillna(df['BsmtQual'].mode()[0], inplace=True)
df['BsmtCond'].fillna(df['BsmtCond'].mode()[0], inplace=True)
df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0], inplace=True)
df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode()[0], inplace=True)
df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0], inplace=True)
df['GarageType'].fillna(df['GarageType'].mode()[0], inplace=True)
df['GarageFinish'].fillna(df['GarageFinish'].mode()[0], inplace=True)
df['GarageQual'].fillna(df['GarageQual'].mode()[0], inplace=True)
df['GarageCond'].fillna(df['GarageCond'].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtQual'].fillna(df['BsmtQual'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtCond'].fillna(df['BsmtCond'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageType'].fillna(df['GarageType'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageFinish'].fillna(df['GarageFinish'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageQual'].fillna(df['GarageQual'].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_18340\2431477288.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageCond'].fillna(df['GarageCond'].mode()[0], inplace=True)

# %%
print(df.isnull().sum().sum() == 0)  # Returns True if no nulls, False otherwise
# Out:
# True

# %%
null_counts = df.isnull().sum()
print(null_counts[null_counts > 0])
# Out:
# Series([], dtype: int64)

# %%
print(df[['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']])
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 GarageType  \
# Id
# 1          Gd       TA           No          GLQ          Unf     Attchd
# 2          Gd       TA           Gd          ALQ          Unf     Attchd
# 3          Gd       TA           Mn          GLQ          Unf     Attchd
# 4          TA       Gd           No          ALQ          Unf     Detchd
# 5          Gd       TA           Av          GLQ          Unf     Attchd
# 6          Gd       TA           No          GLQ          Unf     Attchd
# 7          Ex       TA           Av          GLQ          Unf     Attchd
# 8          Gd       TA           Mn          ALQ          BLQ     Attchd
# 9          TA       TA           No          Unf          Unf     Detchd
# 10         TA       TA           No          GLQ          Unf     Attchd
# 11         TA       TA           No          Rec          Unf     Detchd
# 12         Ex       TA           No          GLQ          Unf    BuiltIn
# 13         TA       TA           No          ALQ          Unf     Detchd
# 14         Gd       TA           Av          Unf          Unf     Attchd
# 15         TA       TA           No          BLQ          Unf     Attchd
# 16         TA       TA           No          Unf          Unf     Detchd
# 17         TA       TA           No          ALQ          Unf     Attchd
# 18         TA       TA           No          Unf          Unf    CarPort
# 19         TA       TA           No          GLQ          Unf     Detchd
# 20         TA       TA           No          LwQ          Unf     Attchd
# 21         Ex       TA           Av          Unf          Unf    BuiltIn
# 22         TA       TA           No          Unf          Unf     Attchd
# 23         Gd       TA           No          Unf          Unf     Attchd
# 24         Gd       TA           No          GLQ          Unf     Attchd
# 25         TA       TA           Mn          Rec          ALQ     Attchd
# 26         Gd       TA           No          Unf          Unf     Attchd
# 27         TA       TA           Mn          BLQ          Rec     Detchd
# 28         Ex       TA           No          GLQ          Unf     Attchd
# 29         TA       TA           Gd          BLQ          Unf     Attchd
# 30         TA       TA           No          Unf          Unf     Detchd
# 31         TA       TA           No          Unf          Unf     Detchd
# 32         TA       TA           No          Unf          Unf     Attchd
# 33         Ex       TA           Av          Unf          Unf     Attchd
# 34         TA       TA           No          Rec          Unf     Attchd
# 35         Ex       TA           No          GLQ          Unf     Attchd
# 36         Ex       TA           Av          Unf          Unf    BuiltIn
# 37         Gd       TA           No          Unf          Unf     Attchd
# 38         TA       TA           No          Rec          Unf     Attchd
# 39         TA       TA           No          GLQ          Unf     Detchd
# 40         TA       TA           No          Unf          Unf     Attchd
# 41         TA       TA           No          Rec          Unf     Attchd
# 42         TA       TA           Gd          BLQ          Unf     Attchd
# 43         Gd       TA           Av          ALQ          LwQ     Attchd
# 44         Gd       TA           Av          LwQ          BLQ     Detchd
# 45         TA       TA           No          ALQ          BLQ     Attchd
# 46         Ex       TA           No          GLQ          Unf     Attchd
# 47         Ex       TA           No          GLQ          Unf     Attchd
# 48         Gd       TA           Av          GLQ          Unf     Attchd
# 49         TA       TA           No          Unf          Unf     Attchd
# 50         TA       TA           No          BLQ          Unf     Attchd
# 51         Gd       TA           Av          GLQ          Unf     Attchd
# 52         TA       TA           No          Unf          Unf     Detchd
# 53         Gd       TA           Gd          LwQ          GLQ    CarPort
# 54         Ex       TA           Gd          GLQ          Unf     Attchd
# 55         TA       TA           No          ALQ          Unf     Detchd
# 56         TA       TA           No          BLQ          Unf     Attchd
# 57         Gd       TA           No          GLQ          Unf     Attchd
# 58         Gd       TA           No          Unf          Unf     Attchd
# 59         Ex       TA           Gd          Unf          Unf    BuiltIn
# 60         TA       TA           Av          ALQ          Unf     Detchd
# 61         Gd       TA           No          ALQ          Unf     Detchd
# 62         TA       Fa           No          Unf          Unf     Detchd
# 63         Gd       Gd           Mn          GLQ          Unf     Attchd
# 64         TA       TA           No          Unf          Unf     Detchd
# 65         Gd       TA           No          GLQ          Unf     Attchd
# 66         Ex       TA           Av          Unf          Unf    BuiltIn
# 67         Gd       TA           Gd          GLQ          Unf     Attchd
# 68         Gd       TA           Av          GLQ          Unf     Attchd
# 69         TA       TA           No          Unf          Unf     Attchd
# 70         TA       TA           No          BLQ          Unf     Attchd
# 71         Gd       TA           Gd          ALQ          Unf     Attchd
# 72         TA       TA           No          ALQ          Unf     Detchd
# 73         Gd       TA           No          Unf          Unf     Attchd
# 74         TA       TA           No          ALQ          BLQ     Attchd
# 75         Fa       TA           No          Unf          Unf     Detchd
# 76         Gd       TA           Gd          GLQ          Unf    BuiltIn
# 77         TA       TA           No          ALQ          Unf     Detchd
# 78         TA       TA           No          BLQ          GLQ     Detchd
# 79         TA       TA           No          Unf          Unf     Attchd
# 80         TA       TA           No          Unf          Unf     Detchd
# 81         Gd       TA           No          Rec          Unf     Attchd
# 82         Ex       Gd           No          GLQ          Unf     Attchd
# 83         Gd       TA           No          GLQ          Unf     Attchd
# 84         TA       TA           No          Unf          Unf     Detchd
# 85         Gd       TA           No          Unf          Unf    BuiltIn
# 86         Gd       TA           No          Unf          Unf     Attchd
# 87         Gd       TA           Av          Unf          Unf    BuiltIn
# 88         Gd       TA           Av          Unf          Unf     Detchd
# 89         TA       Fa           No          Unf          Unf     Attchd
# 90         Gd       TA           No          GLQ          Unf     Attchd
# 91         TA       TA           No          Unf          Unf     Detchd
# 92         TA       TA           No          Rec          Unf     Attchd
# 93         Gd       TA           No          ALQ          Unf     Detchd
# 94         TA       Fa           Mn          Rec          Unf     Detchd
# 95         Gd       TA           No          GLQ          Unf     Attchd
# 96         Gd       Gd           No          ALQ          Unf    BuiltIn
# 97         Gd       TA           Av          ALQ          Unf     Attchd
# 98         TA       TA           No          Rec          Unf     Attchd
# 99         TA       TA           No          ALQ          Unf    Basment
# 100        TA       TA           No          ALQ          Unf     Attchd
# 101        TA       TA           Mn          ALQ          Unf     Attchd
# 102        Gd       TA           No          Unf          Unf     Attchd
# 103        TA       TA           No          Unf          Unf     Attchd
# 104        Gd       TA           No          Unf          Unf     Attchd
# 105        TA       TA           No          LwQ          Unf     Detchd
# 106        Ex       TA           No          Unf          Unf     Attchd
# 107        Fa       TA           No          Unf          Unf     Detchd
# 108        TA       TA           No          ALQ          BLQ     Detchd
# 109        TA       TA           No          Unf          Unf     Attchd
# 110        Gd       TA           No          BLQ          Unf     Attchd
# 111        TA       Fa           No          Rec          Unf     Attchd
# 112        Gd       TA           No          GLQ          Unf    BuiltIn
# 113        Ex       TA           Av          GLQ          Unf    BuiltIn
# 114        Gd       TA           Mn          ALQ          Rec    Basment
# 115        TA       TA           No          ALQ          LwQ     Detchd
# 116        Gd       TA           No          GLQ          Unf     Detchd
# 117        TA       TA           No          LwQ          BLQ     Attchd
# 118        Gd       TA           No          Unf          Unf     Attchd
# 119        Gd       TA           Mn          GLQ          Unf     Attchd
# 120        Gd       TA           No          Unf          Unf     Attchd
# 121        TA       TA           Gd          ALQ          Unf     Attchd
# 122        TA       TA           No          Unf          Unf     Detchd
# 123        TA       TA           No          BLQ          Unf     Attchd
# 124        Gd       TA           No          GLQ          Unf     Attchd
# 125        Gd       Fa           No          Unf          Unf     Attchd
# 126        TA       TA           Av          GLQ          Unf     Attchd
# 127        Gd       TA           No          ALQ          Unf     Attchd
# 128        TA       TA           No          LwQ          Unf     Attchd
# 129        TA       TA           No          BLQ          Unf     Attchd
# 130        TA       TA           No          Rec          BLQ     2Types
# 131        TA       TA           No          Rec          Unf     Attchd
# 132        Gd       TA           No          GLQ          Unf    BuiltIn
# 133        TA       TA           No          Rec          Unf     Detchd
# 134        Ex       TA           No          GLQ          Unf     Attchd
# 135        TA       TA           No          Rec          Unf     Attchd
# 136        TA       TA           No          Unf          Unf     Attchd
# 137        TA       TA           No          BLQ          Unf     Attchd
# 138        TA       TA           No          Unf          Unf     2Types
# 139        Gd       TA           Mn          GLQ          Unf     Attchd
# 140        Gd       TA           No          GLQ          Unf     Attchd
# 141        TA       TA           No          ALQ          Unf     Attchd
# 142        Gd       TA           Av          GLQ          Unf     Attchd
# 143        TA       TA           No          Rec          Unf     Detchd
# 144        Gd       TA           Gd          GLQ          Unf     Attchd
# 145        TA       TA           No          Rec          Unf     Detchd
# 146        Gd       TA           No          Unf          Unf     Detchd
# 147        TA       TA           No          BLQ          Unf     Detchd
# 148        Gd       TA           No          Unf          Unf    BuiltIn
# 149        Gd       TA           No          GLQ          Unf     Attchd
# 150        Gd       TA           No          Unf          Unf     Detchd
# 151        TA       TA           Av          BLQ          Unf     Attchd
# 152        Ex       TA           Gd          GLQ          Unf     Attchd
# 153        TA       TA           No          Rec          Unf     Attchd
# 154        Gd       TA           Gd          BLQ          ALQ     Attchd
# 155        TA       TA           No          Unf          Unf     Detchd
# 156        TA       TA           No          Unf          Unf     Attchd
# 157        TA       TA           No          Unf          Unf     Detchd
# 158        Ex       TA           No          Unf          Unf    BuiltIn
# 159        Gd       TA           No          GLQ          Unf     Attchd
# 160        Gd       TA           Mn          GLQ          Unf     Attchd
# 161        Gd       TA           No          BLQ          Unf     Attchd
# 162        Ex       TA           Av          GLQ          Unf    BuiltIn
# 163        Gd       TA           Mn          BLQ          Unf     Attchd
# 164        TA       TA           No          Unf          Unf     Attchd
# 165        TA       TA           Mn          LwQ          Unf     Detchd
# 166        TA       TA           No          ALQ          Rec     Attchd
# 167        TA       TA           No          LwQ          BLQ     Attchd
# 168        Ex       TA           No          GLQ          Unf     Attchd
# 169        Gd       TA           No          Unf          Unf     Attchd
# 170        Gd       TA           No          Unf          Unf     Attchd
# 171        TA       TA           No          Rec          Unf     Detchd
# 172        TA       Gd           Gd          BLQ          Unf     Attchd
# 173        Gd       Gd           No          GLQ          Rec     Attchd
# 174        TA       TA           No          ALQ          Rec     Attchd
# 175        Gd       Fa           No          ALQ          LwQ     Attchd
# 176        TA       Gd           Av          ALQ          Unf     Attchd
# 177        Gd       TA           No          GLQ          Unf     Attchd
# 178        TA       TA           No          ALQ          BLQ     Attchd
# 179        Ex       TA           No          GLQ          Unf     Attchd
# 180        TA       TA           No          Unf          Unf     Detchd
# 181        Gd       TA           No          GLQ          Unf     Detchd
# 182        Fa       TA           No          LwQ          Unf     Detchd
# 183        TA       TA           No          Unf          Unf     Attchd
# 184        Gd       TA           No          Unf          Unf     Detchd
# 185        Fa       TA           No          Unf          Unf     Attchd
# 186        TA       TA           Mn          Unf          Unf     Detchd
# 187        Gd       TA           Av          GLQ          Unf     Attchd
# 188        Fa       TA           No          Unf          Unf     Detchd
# 189        Gd       TA           Av          GLQ          Unf     Detchd
# 190        Ex       TA           Av          GLQ          Unf     Attchd
# 191        Gd       Gd           No          Rec          Unf     Detchd
# 192        TA       TA           No          ALQ          Unf     Attchd
# 193        Gd       TA           Av          GLQ          Unf     Attchd
# 194        Gd       TA           No          Unf          Unf     Detchd
# 195        TA       TA           Av          ALQ          Unf     Detchd
# 196        Gd       TA           No          ALQ          Unf     Attchd
# 197        Ex       TA           No          GLQ          Unf     Attchd
# 198        TA       TA           No          GLQ          LwQ     Detchd
# 199        TA       TA           No          Unf          Unf     Attchd
# 200        Ex       TA           Av          GLQ          Unf     Attchd
# 201        Gd       TA           No          Unf          Unf     Attchd
# 202        TA       TA           No          ALQ          LwQ     Detchd
# 203        Fa       TA           No          LwQ          Unf     Attchd
# 204        Gd       TA           Av          GLQ          Unf     Attchd
# 205        TA       TA           No          LwQ          Unf     Detchd
# 206        Gd       TA           No          Unf          Unf     Attchd
# 207        TA       TA           No          Unf          Unf     Attchd
# 208        TA       TA           No          ALQ          Rec     Attchd
# 209        Gd       TA           Gd          GLQ          Unf     Attchd
# 210        Gd       TA           No          Rec          Unf     Attchd
# 211        TA       TA           No          Rec          Unf     Attchd
# 212        Gd       TA           Mn          GLQ          Unf     Attchd
# 213        Gd       TA           No          GLQ          Unf     Attchd
# 214        Gd       TA           No          ALQ          Unf     Attchd
# 215        Gd       TA           No          GLQ          Unf     Attchd
# 216        TA       TA           No          BLQ          Unf     Attchd
# 217        Gd       TA           Mn          GLQ          Unf     Attchd
# 218        TA       TA           No          Unf          Unf     Detchd
# 219        TA       TA           No          BLQ          Unf     Attchd
# 220        Gd       TA           Av          GLQ          Unf     Attchd
# 221        Gd       TA           Mn          Unf          Unf     Attchd
# 222        Gd       TA           No          Unf          Unf    BuiltIn
# 223        Gd       TA           No          ALQ          Unf     Attchd
# 224        TA       TA           No          ALQ          LwQ     Detchd
# 225        Ex       TA           Gd          GLQ          Unf     Attchd
# 226        TA       TA           No          Unf          Unf     Detchd
# 227        Gd       TA           No          GLQ          Unf     Attchd
# 228        TA       TA           No          Rec          Unf     Detchd
# 229        TA       TA           No          ALQ          Unf     Detchd
# 230        Gd       TA           Av          GLQ          Unf     Attchd
# 231        TA       TA           No          Unf          Unf     Attchd
# 232        Gd       TA           No          GLQ          Unf     Attchd
# 233        TA       TA           No          Unf          Unf     Attchd
# 234        TA       Gd           Av          LwQ          ALQ     Attchd
# 236        TA       TA           No          ALQ          Unf     Detchd
# 237        Gd       TA           Av          GLQ          Unf     Attchd
# 238        Gd       TA           No          BLQ          Unf     Attchd
# 239        Ex       TA           No          Unf          Unf     Attchd
# 240        TA       Fa           No          LwQ          Unf     Detchd
# 241        Gd       TA           Av          GLQ          Unf     Attchd
# 242        TA       TA           No          ALQ          Unf     Attchd
# 243        TA       TA           No          Unf          Unf     Attchd
# 244        Gd       TA           No          Unf          Unf     Attchd
# 245        Gd       TA           No          GLQ          Unf     Attchd
# 246        Gd       TA           Av          GLQ          Unf     Attchd
# 247        Fa       TA           No          Unf          Unf     Detchd
# 248        TA       TA           No          Unf          Unf     Attchd
# 249        Gd       TA           No          Unf          Unf     Attchd
# 250        Gd       TA           Gd          Rec          Unf     Attchd
# 251        TA       TA           No          Unf          Unf     Attchd
# 252        Gd       TA           Gd          GLQ          Unf     Attchd
# 253        Gd       TA           No          Unf          Unf     Attchd
# 254        Gd       TA           Gd          LwQ          ALQ     Attchd
# 255        TA       TA           No          Rec          Unf     Attchd
# 256        Gd       TA           No          Unf          Unf    BuiltIn
# 257        Gd       TA           No          Rec          Unf     Attchd
# 258        Gd       TA           No          GLQ          Unf     Attchd
# 259        Gd       TA           No          GLQ          Unf     Attchd
# 260        TA       TA           No          Unf          Unf     Detchd
# 261        TA       TA           Gd          Rec          ALQ     Attchd
# 262        Ex       TA           No          Unf          Unf    BuiltIn
# 263        Gd       Gd           Av          ALQ          Unf     Attchd
# 264        TA       TA           No          LwQ          ALQ     Detchd
# 265        Fa       TA           No          Unf          Unf     Detchd
# 266        Gd       TA           No          GLQ          LwQ     Attchd
# 267        Gd       TA           Av          GLQ          Unf     Attchd
# 268        TA       TA           No          LwQ          Unf     Detchd
# 269        TA       TA           No          ALQ          Rec     Detchd
# 270        TA       Gd           No          BLQ          Unf     Attchd
# 271        Gd       TA           Mn          Unf          Unf     Attchd
# 272        Gd       TA           Gd          LwQ          GLQ     Attchd
# 273        Gd       TA           No          GLQ          Unf     Attchd
# 274        TA       TA           No          Rec          LwQ     Attchd
# 275        TA       TA           Gd          ALQ          Unf     Attchd
# 276        TA       TA           No          Unf          Unf     Detchd
# 277        Ex       TA           No          Unf          Unf     Attchd
# 278        TA       TA           No          LwQ          Unf     Detchd
# 279        Ex       TA           Gd          Unf          Unf     Attchd
# 280        Gd       TA           No          BLQ          Unf     Attchd
# 281        Gd       TA           Av          GLQ          Unf     Attchd
# 282        Gd       TA           No          GLQ          Unf     Attchd
# 283        Gd       TA           No          GLQ          Unf     Attchd
# 284        Gd       TA           No          Unf          Unf     Attchd
# 285        Gd       TA           No          GLQ          Unf     Attchd
# 286        Gd       TA           No          Unf          Unf     Detchd
# 287        TA       TA           No          Rec          Unf     Attchd
# 288        TA       TA           No          BLQ          Unf     Attchd
# 289        TA       TA           No          BLQ          Unf     Detchd
# 290        TA       TA           No          Unf          Unf     Detchd
# 291        Gd       TA           Av          Unf          Unf     Attchd
# 292        TA       Fa           No          Rec          Unf     Attchd
# 293        TA       TA           No          LwQ          Unf     Attchd
# 294        TA       TA           No          ALQ          Unf     Attchd
# 295        TA       TA           No          GLQ          Unf     Attchd
# 296        TA       TA           Av          GLQ          Unf     Detchd
# 297        TA       TA           No          BLQ          Unf     Attchd
# 298        Gd       TA           No          BLQ          Unf     Detchd
# 299        TA       TA           No          ALQ          Rec     Attchd
# 300        TA       TA           No          Unf          Unf     Attchd
# 301        TA       TA           Mn          BLQ          Unf     Attchd
# 302        Gd       TA           No          GLQ          Unf    BuiltIn
# 303        Gd       TA           No          Unf          Unf     Attchd
# 304        TA       TA           No          ALQ          Unf     Attchd
# 305        TA       TA           No          Unf          Unf     Attchd
# 306        Gd       TA           No          GLQ          Unf     Attchd
# 307        Gd       TA           No          ALQ          Unf     Attchd
# 308        TA       TA           No          Unf          Unf     Attchd
# 309        TA       TA           No          BLQ          Unf     Detchd
# 310        Ex       TA           Gd          GLQ          Unf     Attchd
# 311        Gd       TA           No          ALQ          Unf     Attchd
# 312        TA       TA           No          ALQ          Unf     Detchd
# 313        Gd       TA           Mn          Rec          Unf     Detchd
# 314        Gd       TA           Gd          ALQ          Rec     Attchd
# 315        TA       Gd           No          LwQ          Unf     Detchd
# 316        Gd       TA           No          GLQ          Unf     Attchd
# 317        Gd       TA           No          GLQ          Unf     Attchd
# 318        Gd       TA           Av          Unf          Unf     Attchd
# 319        Gd       TA           Gd          GLQ          Unf     Attchd
# 320        Gd       TA           Av          GLQ          Unf     Attchd
# 321        Ex       Gd           Av          Unf          Unf     Attchd
# 322        Ex       TA           Av          GLQ          Unf    BuiltIn
# 323        TA       TA           Gd          LwQ          ALQ     Attchd
# 324        TA       TA           No          ALQ          Unf     Attchd
# 325        Gd       TA           No          Unf          Unf    BuiltIn
# 326        TA       TA           Av          BLQ          Unf     Detchd
# 327        Gd       TA           Gd          GLQ          Unf     Attchd
# 328        TA       TA           No          Rec          Unf     Attchd
# 329        TA       TA           No          Unf          Unf     Detchd
# 330        TA       TA           Mn          Unf          Unf     Detchd
# 331        TA       TA           No          GLQ          Rec     Detchd
# 332        TA       TA           No          Rec          Unf     Attchd
# 333        Gd       TA           No          GLQ          Unf     Attchd
# 334        Gd       TA           Av          GLQ          Unf     Attchd
# 335        Gd       TA           Gd          GLQ          Unf     Attchd
# 336        TA       TA           Gd          ALQ          BLQ     Attchd
# 337        Ex       TA           Gd          GLQ          Unf     Attchd
# 338        Gd       TA           Av          GLQ          Unf     Attchd
# 339        Gd       TA           Mn          ALQ          Unf     Attchd
# 340        TA       Fa           No          Rec          Unf     Attchd
# 341        Gd       TA           No          Unf          Unf     Attchd
# 342        TA       Fa           No          Unf          Unf    CarPort
# 343        TA       TA           No          Unf          Unf     Detchd
# 344        Ex       TA           No          GLQ          Unf     Attchd
# 345        Gd       TA           No          Rec          BLQ     Attchd
# 346        TA       TA           No          Unf          Unf     Detchd
# 347        TA       TA           Mn          BLQ          Unf     Attchd
# 348        TA       TA           No          BLQ          Unf     Attchd
# 349        Gd       TA           No          GLQ          Unf    BuiltIn
# 350        Ex       TA           No          GLQ          Unf     Attchd
# 351        Ex       TA           No          Unf          Unf     Attchd
# 352        Gd       TA           Gd          GLQ          Unf     Attchd
# 353        TA       Fa           Mn          LwQ          Rec     Detchd
# 354        TA       TA           No          Unf          Unf     Detchd
# 355        TA       TA           No          LwQ          Unf     Attchd
# 356        Gd       Gd           No          ALQ          BLQ     Attchd
# 357        Gd       TA           No          GLQ          Unf     Attchd
# 358        Gd       TA           No          ALQ          Unf     Attchd
# 359        TA       TA           Av          BLQ          Rec    BuiltIn
# 360        Gd       TA           Av          GLQ          Unf     Attchd
# 361        Gd       TA           Av          GLQ          Unf     Attchd
# 362        TA       TA           No          Rec          Unf     Detchd
# 363        TA       TA           No          Unf          Unf    BuiltIn
# 364        TA       TA           No          ALQ          Unf     Detchd
# 365        Gd       TA           Mn          GLQ          Unf     Attchd
# 366        TA       Fa           No          Rec          Unf     Detchd
# 367        Gd       TA           No          BLQ          Unf     Attchd
# 368        Gd       TA           Gd          GLQ          Unf    Basment
# 369        TA       TA           No          LwQ          Unf     Attchd
# 370        TA       TA           No          ALQ          Rec     Detchd
# 371        Gd       TA           No          Unf          Unf     Attchd
# 372        TA       TA           No          Unf          Unf     Detchd
# 373        Gd       TA           No          ALQ          LwQ     Attchd
# 374        TA       TA           No          BLQ          LwQ     Attchd
# 375        Gd       TA           No          Unf          Unf    BuiltIn
# 376        Fa       Po           Gd          BLQ          Unf     Attchd
# 377        Gd       TA           Av          GLQ          Unf     Detchd
# 378        Gd       TA           No          Unf          Unf     Attchd
# 379        Ex       TA           Av          GLQ          Unf     Attchd
# 380        Gd       TA           No          Unf          Unf     Attchd
# 381        TA       TA           No          LwQ          Unf     Detchd
# 382        Gd       Gd           No          Unf          Unf     Attchd
# 383        Gd       TA           Av          Unf          Unf     Attchd
# 384        Fa       Fa           No          Unf          Unf     Detchd
# 385        Gd       TA           Av          GLQ          Unf     Attchd
# 386        Gd       TA           No          GLQ          Unf     Attchd
# 387        TA       TA           No          Unf          Unf     Attchd
# 388        TA       TA           Av          ALQ          Unf     Detchd
# 389        Gd       TA           No          Unf          Unf     Attchd
# 390        Ex       TA           Av          GLQ          Unf    BuiltIn
# 391        TA       Gd           No          Rec          BLQ     Detchd
# 392        Ex       TA           No          ALQ          Unf    BuiltIn
# 393        TA       TA           No          Unf          Unf     Attchd
# 394        TA       TA           No          Rec          Unf     Attchd
# 395        TA       TA           No          Unf          Unf     Detchd
# 396        TA       TA           Av          BLQ          Unf     Attchd
# 397        TA       TA           Av          Rec          Unf     Detchd
# 398        TA       TA           No          ALQ          Unf     Attchd
# 399        Fa       Po           No          Unf          Unf     Detchd
# 400        Gd       TA           No          GLQ          Unf     Attchd
# 401        Gd       TA           No          GLQ          Unf     Attchd
# 402        Gd       TA           Av          GLQ          Unf     Attchd
# 403        TA       TA           No          Unf          Unf     Detchd
# 404        Gd       TA           No          Unf          Unf    BuiltIn
# 405        Gd       TA           No          Unf          Unf    BuiltIn
# 406        TA       TA           No          BLQ          Unf     Attchd
# 407        TA       TA           No          Unf          Unf     Detchd
# 408        Gd       TA           No          Unf          Unf     Attchd
# 409        Ex       Gd           No          Unf          Unf     Attchd
# 410        Ex       TA           No          GLQ          Unf     Attchd
# 411        TA       Fa           No          Unf          Unf     Attchd
# 412        TA       TA           Mn          Rec          Unf     Attchd
# 413        Ex       TA           Av          GLQ          Unf     Attchd
# 414        TA       TA           No          Unf          Unf     Detchd
# 415        Gd       TA           No          BLQ          GLQ     Attchd
# 416        Gd       TA           Av          GLQ          Unf     Attchd
# 417        TA       TA           No          ALQ          Unf     Attchd
# 418        Gd       TA           No          BLQ          Unf     Detchd
# 419        TA       TA           No          ALQ          Unf     Detchd
# 420        TA       TA           No          BLQ          Unf     Attchd
# 421        Gd       Gd           Gd          GLQ          Unf     Attchd
# 422        Gd       TA           No          ALQ          Unf     Attchd
# 423        TA       TA           No          Unf          Unf     Attchd
# 424        Gd       TA           No          GLQ          Unf     Attchd
# 425        Gd       TA           No          LwQ          Unf     Attchd
# 426        TA       TA           No          Unf          Unf     Detchd
# 427        Gd       TA           Gd          GLQ          Unf     Attchd
# 428        TA       TA           No          Rec          Unf     Detchd
# 429        Gd       TA           No          GLQ          Unf     Attchd
# 430        Gd       TA           Mn          GLQ          Unf     Attchd
# 431        TA       TA           No          ALQ          Unf     Detchd
# 432        TA       TA           No          Unf          Unf     Attchd
# 433        TA       TA           No          ALQ          Unf     Detchd
# 434        Gd       TA           No          Unf          Unf     Attchd
# 435        Gd       TA           Av          ALQ          Unf     Attchd
# 436        Gd       TA           Av          GLQ          ALQ     Attchd
# 437        Fa       TA           No          Unf          Unf     Detchd
# 438        TA       TA           No          Unf          Unf     Detchd
# 439        TA       TA           No          LwQ          Unf     Detchd
# 440        TA       Fa           Mn          Unf          Unf     Detchd
# 441        Ex       TA           Gd          GLQ          ALQ     Attchd
# 442        TA       TA           No          ALQ          Unf     Attchd
# 443        TA       TA           No          Unf          Unf     Detchd
# 444        Ex       TA           Av          Unf          Unf     Attchd
# 445        Gd       TA           No          GLQ          Unf     Attchd
# 446        TA       TA           No          Unf          Unf     Attchd
# 447        TA       TA           No          ALQ          Rec     Attchd
# 448        Gd       TA           No          Unf          Unf     Attchd
# 449        TA       TA           No          Unf          Unf     Detchd
# 450        TA       TA           No          ALQ          Unf     Detchd
# 451        TA       TA           No          Unf          Unf     Detchd
# 452        Gd       TA           Gd          ALQ          Unf     Attchd
# 453        Ex       TA           No          ALQ          Unf     Attchd
# 454        Gd       TA           No          Unf          Unf     Attchd
# 455        TA       TA           No          ALQ          Unf     Detchd
# 456        TA       TA           No          ALQ          Unf     Attchd
# 457        TA       TA           No          Unf          Unf     Detchd
# 458        Gd       TA           Gd          BLQ          Unf     Attchd
# 459        TA       TA           No          Unf          Unf     Detchd
# 460        TA       TA           No          LwQ          Unf     Detchd
# 461        Gd       TA           No          GLQ          Unf    BuiltIn
# 462        Gd       Gd           No          ALQ          BLQ     Detchd
# 463        TA       TA           No          Rec          BLQ     Detchd
# 464        TA       TA           No          LwQ          Unf     Detchd
# 465        Gd       TA           No          Rec          Unf     Attchd
# 466        Gd       TA           No          Unf          Unf     Attchd
# 467        TA       Gd           Gd          GLQ          Unf     Attchd
# 468        TA       TA           No          LwQ          Unf     Attchd
# 469        Gd       TA           No          Unf          Unf     Attchd
# 470        Gd       TA           No          GLQ          Unf     Attchd
# 471        Gd       TA           Av          GLQ          BLQ     Attchd
# 472        Gd       TA           No          Unf          Unf     Attchd
# 473        Gd       TA           Gd          GLQ          Unf    Basment
# 474        Ex       TA           Gd          GLQ          Unf     Attchd
# 475        Gd       TA           Av          GLQ          Unf     Attchd
# 476        TA       TA           No          GLQ          Unf     Detchd
# 477        Gd       TA           Gd          GLQ          Unf     Attchd
# 478        Gd       TA           Av          Unf          Unf    BuiltIn
# 479        Ex       TA           Gd          GLQ          Unf     Attchd
# 480        Fa       TA           No          Rec          Unf     Detchd
# 481        Ex       TA           Gd          GLQ          Unf     Attchd
# 482        Ex       TA           Gd          GLQ          Unf     Attchd
# 483        TA       TA           No          ALQ          Unf     Attchd
# 484        Ex       TA           No          GLQ          Unf     Attchd
# 485        TA       TA           No          ALQ          Unf     Detchd
# 486        TA       TA           No          ALQ          Unf     Attchd
# 487        TA       TA           No          ALQ          Unf     Attchd
# 488        Gd       TA           Av          ALQ          Unf     Attchd
# 489        TA       Fa           No          BLQ          Unf     Attchd
# 490        Gd       TA           Av          GLQ          Unf     Attchd
# 491        Gd       TA           Mn          Unf          Unf    BuiltIn
# 492        TA       TA           No          BLQ          Rec     Attchd
# 493        Gd       TA           No          Unf          Unf     Attchd
# 494        TA       TA           No          BLQ          LwQ     Detchd
# 495        Fa       TA           No          Unf          Unf     Attchd
# 496        TA       TA           No          Rec          Unf     Attchd
# 497        Gd       TA           No          GLQ          Unf     Attchd
# 498        TA       TA           No          Rec          Unf     Detchd
# 499        TA       TA           No          ALQ          Unf     Attchd
# 500        TA       TA           No          BLQ          LwQ     Attchd
# 501        TA       TA           No          BLQ          Unf     Detchd
# 502        Gd       TA           No          GLQ          Unf     Attchd
# 503        TA       TA           No          ALQ          GLQ     Detchd
# 504        TA       TA           No          ALQ          Unf     Attchd
# 505        TA       TA           No          ALQ          Rec     Attchd
# 506        TA       TA           No          Unf          Unf     Detchd
# 507        Gd       TA           No          GLQ          Unf     Attchd
# 508        Gd       TA           No          GLQ          Unf     Attchd
# 509        TA       TA           No          Rec          Unf     Detchd
# 510        TA       TA           No          ALQ          Unf     Attchd
# 511        TA       TA           No          BLQ          Rec    CarPort
# 512        Gd       TA           No          Unf          Unf     Attchd
# 513        TA       TA           No          BLQ          LwQ     Detchd
# 514        TA       TA           No          ALQ          Unf     Attchd
# 515        TA       TA           No          Unf          Unf     Detchd
# 516        Ex       TA           No          GLQ          Unf     Attchd
# 517        TA       TA           No          Unf          Unf     Attchd
# 518        Gd       TA           No          Unf          Unf     Attchd
# 519        Gd       TA           Mn          GLQ          Unf     Attchd
# 520        Gd       TA           No          Unf          Unf     Detchd
# 521        TA       TA           No          Unf          Unf     Attchd
# 522        TA       TA           No          Rec          Unf     Attchd
# 523        TA       TA           No          ALQ          Unf     Detchd
# 524        Ex       TA           Gd          GLQ          Unf    BuiltIn
# 525        Gd       TA           No          GLQ          Unf     Attchd
# 526        Gd       TA           No          Unf          Unf     Attchd
# 527        Gd       TA           No          Rec          Unf     Attchd
# 528        Ex       TA           Av          GLQ          Unf     Attchd
# 529        TA       TA           Mn          ALQ          Unf     Attchd
# 531        Gd       TA           Av          GLQ          Unf     Attchd
# 532        Fa       Fa           Mn          Unf          Unf     Detchd
# 533        TA       TA           No          Unf          Unf     Detchd
# 534        TA       TA           No          Unf          Unf     Attchd
# 535        Ex       Gd           Av          Unf          Unf     Attchd
# 536        Gd       TA           Gd          GLQ          Unf     Attchd
# 537        Gd       TA           Av          Unf          Unf     Attchd
# 538        TA       TA           No          BLQ          Unf     Detchd
# 539        TA       TA           No          BLQ          Unf     Attchd
# 540        Gd       TA           Av          GLQ          Unf     Attchd
# 541        Ex       TA           Av          GLQ          Unf     Attchd
# 542        Gd       TA           No          Unf          Unf    BuiltIn
# 543        Ex       TA           No          LwQ          GLQ     Attchd
# 544        Gd       TA           Av          GLQ          LwQ     Attchd
# 545        Gd       Gd           Av          GLQ          Unf     Attchd
# 546        Gd       Gd           No          GLQ          LwQ     Attchd
# 547        Gd       TA           No          Rec          Unf     Detchd
# 548        Gd       TA           Av          ALQ          Unf     Detchd
# 549        TA       TA           No          LwQ          Rec     Detchd
# 550        Gd       TA           No          Unf          Unf    BuiltIn
# 551        Gd       TA           No          ALQ          Unf     Attchd
# 552        TA       TA           No          Rec          Unf     Attchd
# 553        Ex       TA           Av          Unf          Unf     Attchd
# 554        TA       TA           No          Unf          Unf     Detchd
# 555        Gd       TA           No          GLQ          Unf    BuiltIn
# 556        TA       Fa           No          Unf          Unf     Detchd
# 557        TA       TA           No          Rec          Unf     Attchd
# 558        TA       TA           No          Rec          Unf    CarPort
# 559        Gd       TA           Gd          GLQ          Unf     Attchd
# 560        Gd       TA           Gd          Unf          Unf     Attchd
# 561        Gd       TA           No          ALQ          Unf     Detchd
# 562        Gd       TA           Av          ALQ          LwQ     Attchd
# 563        TA       TA           No          BLQ          Unf     Attchd
# 564        Gd       TA           Mn          Unf          Unf     Detchd
# 565        Gd       TA           No          GLQ          Unf     Attchd
# 566        Gd       TA           No          Unf          Unf     Detchd
# 567        Gd       Gd           No          Unf          Unf    BuiltIn
# 568        Gd       TA           No          GLQ          Unf     Attchd
# 569        Gd       TA           Gd          GLQ          Unf    BuiltIn
# 570        Gd       TA           Gd          GLQ          Unf     Detchd
# 571        TA       TA           No          LwQ          Unf     Detchd
# 572        TA       TA           No          BLQ          Unf     Attchd
# 573        Ex       TA           Av          Unf          Unf     Attchd
# 574        Gd       TA           No          Unf          Unf    BuiltIn
# 575        TA       TA           Av          ALQ          Unf    BuiltIn
# 576        TA       TA           No          Rec          Unf     Detchd
# 577        TA       TA           No          Unf          Unf     Detchd
# 578        TA       TA           Av          LwQ          ALQ     Attchd
# 579        Gd       TA           No          Unf          Unf     Detchd
# 580        TA       TA           No          Unf          Unf     Attchd
# 581        TA       TA           No          BLQ          Rec     Attchd
# 582        Ex       TA           No          Unf          Unf     Attchd
# 583        Gd       TA           Av          GLQ          Unf     Attchd
# 584        TA       TA           No          Unf          Unf     Detchd
# 585        TA       TA           No          Unf          Unf     Detchd
# 586        Ex       TA           Gd          GLQ          Unf     Attchd
# 587        TA       Gd           Mn          Rec          ALQ     Detchd
# 588        TA       TA           Av          ALQ          Unf     Detchd
# 589        TA       TA           Gd          GLQ          Unf     Attchd
# 590        TA       TA           No          Unf          Unf     Detchd
# 591        Gd       TA           No          GLQ          Unf     Attchd
# 592        Ex       TA           Gd          GLQ          Unf    BuiltIn
# 593        TA       Gd           No          GLQ          Unf     Detchd
# 594        Gd       TA           Av          GLQ          Unf     Attchd
# 595        Gd       TA           No          Unf          Unf     Detchd
# 596        Gd       TA           Gd          GLQ          Unf     Attchd
# 597        TA       TA           No          Unf          Unf     Detchd
# 598        Ex       TA           Av          Unf          Unf     Attchd
# 599        Gd       TA           Mn          ALQ          LwQ     Attchd
# 600        Gd       TA           No          LwQ          GLQ     Attchd
# 601        Gd       TA           Av          GLQ          Unf    BuiltIn
# 602        TA       TA           No          Unf          Unf     Detchd
# 603        Gd       TA           Mn          GLQ          Unf     Attchd
# 604        Gd       TA           No          Unf          Unf     Detchd
# 605        Gd       TA           Mn          GLQ          Unf     Attchd
# 606        TA       TA           No          BLQ          Unf     Attchd
# 607        Gd       TA           No          GLQ          Unf     Detchd
# 608        TA       Gd           No          GLQ          Unf     Attchd
# 609        Gd       TA           Mn          BLQ          Unf    Basment
# 610        TA       TA           Mn          Rec          Unf     Attchd
# 611        Ex       TA           Mn          GLQ          Unf     Attchd
# 612        Gd       TA           Av          ALQ          Unf     Attchd
# 613        Gd       TA           Av          GLQ          Unf    BuiltIn
# 614        Gd       TA           No          ALQ          Unf     Attchd
# 615        Gd       TA           Av          LwQ          GLQ     Attchd
# 616        TA       TA           Gd          GLQ          Unf     Attchd
# 617        Gd       TA           No          GLQ          Unf     Attchd
# 618        TA       TA           No          Unf          Unf     Detchd
# 619        Ex       TA           Av          GLQ          Unf     Attchd
# 620        Gd       TA           Gd          GLQ          Unf     Attchd
# 621        TA       TA           No          BLQ          Unf     Attchd
# 622        TA       TA           No          ALQ          Rec     Attchd
# 623        TA       TA           No          BLQ          Unf     Detchd
# 624        Gd       TA           No          GLQ          Unf     Detchd
# 625        TA       TA           No          Rec          Unf     Attchd
# 626        TA       TA           No          Unf          Unf     Attchd
# 627        TA       TA           No          Unf          Unf     Attchd
# 628        TA       TA           Av          BLQ          LwQ    Basment
# 629        Gd       TA           Av          Rec          Unf     Attchd
# 630        TA       TA           Gd          GLQ          Rec     Attchd
# 631        Fa       Fa           No          Unf          Unf     Detchd
# ...
# 1077          Unf         TA         TA
# 1078          Fin         TA         TA
# 1079          RFn         TA         TA
# 1080          Unf         TA         TA
# 1081          RFn         TA         TA
# 1082          Fin         TA         TA
# 1083          RFn         TA         TA
# 1084          RFn         TA         TA
# 1085          Fin         TA         TA
# 1086          Unf         TA         TA
# 1087          RFn         TA         TA
# 1088          RFn         TA         TA
# 1089          Unf         TA         TA
# 1090          Fin         TA         TA
# 1091          Unf         TA         TA
# 1092          Unf         TA         TA
# 1093          Unf         TA         TA
# 1094          Unf         TA         TA
# 1095          Fin         TA         TA
# 1096          RFn         TA         TA
# 1097          Unf         TA         TA
# 1098          RFn         TA         TA
# 1099          Unf         TA         TA
# 1100          RFn         TA         TA
# 1101          Unf         TA         TA
# 1102          Unf         TA         TA
# 1103          RFn         TA         TA
# 1104          Fin         TA         TA
# 1105          Unf         TA         TA
# 1106          RFn         TA         TA
# 1107          Fin         TA         TA
# 1108          RFn         TA         TA
# 1109          RFn         TA         TA
# 1110          Fin         TA         TA
# 1111          Fin         TA         TA
# 1112          RFn         TA         TA
# 1113          Unf         TA         TA
# 1114          Unf         TA         TA
# 1115          Unf         TA         TA
# 1116          RFn         TA         TA
# 1117          Fin         TA         TA
# 1118          RFn         TA         TA
# 1119          RFn         TA         TA
# 1120          RFn         TA         TA
# 1121          Unf         TA         TA
# 1122          RFn         TA         TA
# 1123          Unf         TA         TA
# 1124          Unf         TA         TA
# 1125          Fin         TA         TA
# 1126          Unf         Fa         Fa
# 1127          Fin         TA         TA
# 1128          Fin         TA         TA
# 1129          Fin         TA         TA
# 1130          Unf         TA         TA
# 1131          Unf         TA         TA
# 1132          Unf         TA         TA
# 1133          Unf         Fa         TA
# 1134          RFn         TA         TA
# 1135          Fin         TA         TA
# 1136          Unf         TA         TA
# 1137          Unf         TA         TA
# 1138          Unf         TA         TA
# 1139          RFn         TA         TA
# 1140          Unf         TA         TA
# 1141          Unf         TA         TA
# 1142          Unf         TA         TA
# 1143          RFn         TA         TA
# 1144          Unf         TA         TA
# 1145          Unf         TA         TA
# 1146          Unf         TA         TA
# 1147          Unf         TA         TA
# 1148          Unf         TA         TA
# 1149          Unf         TA         TA
# 1150          Unf         TA         TA
# 1151          Unf         TA         TA
# 1152          Fin         TA         TA
# 1153          Fin         TA         TA
# 1154          Unf         TA         TA
# 1155          Unf         TA         TA
# 1156          RFn         TA         TA
# 1157          RFn         TA         TA
# 1158          RFn         TA         TA
# 1159          RFn         TA         TA
# 1160          RFn         Gd         TA
# 1161          Unf         TA         TA
# 1162          Unf         TA         TA
# 1163          Fin         TA         TA
# 1164          Unf         Fa         TA
# 1165          Unf         TA         TA
# 1166          RFn         TA         TA
# 1167          RFn         TA         TA
# 1168          Fin         TA         TA
# 1169          Unf         TA         TA
# 1170          Fin         TA         TA
# 1171          Fin         TA         TA
# 1172          RFn         TA         TA
# 1173          Fin         TA         TA
# 1174          Unf         TA         TA
# 1175          Unf         TA         TA
# 1176          Fin         TA         TA
# 1177          Unf         TA         TA
# 1178          Unf         TA         TA
# 1179          Unf         Fa         TA
# 1180          Unf         TA         TA
# 1181          Fin         TA         TA
# 1182          Fin         TA         TA
# 1183          Fin         TA         TA
# 1184          Unf         TA         TA
# 1185          RFn         TA         TA
# 1186          Unf         TA         TA
# 1187          Unf         Fa         Fa
# 1188          RFn         TA         TA
# 1189          RFn         TA         TA
# 1190          Fin         TA         TA
# 1191          Fin         TA         TA
# 1192          Unf         TA         TA
# 1193          Unf         TA         Fa
# 1194          Fin         TA         TA
# 1195          Fin         TA         TA
# 1196          Fin         TA         TA
# 1197          Fin         TA         TA
# 1198          Unf         TA         TA
# 1199          RFn         TA         TA
# 1200          Unf         TA         TA
# 1201          Unf         TA         TA
# 1202          RFn         TA         TA
# 1203          Unf         TA         TA
# 1204          Unf         TA         TA
# 1205          RFn         TA         TA
# 1206          RFn         TA         TA
# 1207          Unf         TA         TA
# 1208          RFn         TA         TA
# 1209          Unf         TA         TA
# 1210          RFn         TA         TA
# 1211          RFn         TA         TA
# 1212          RFn         TA         TA
# 1213          Unf         TA         TA
# 1214          Unf         TA         TA
# 1215          Unf         TA         TA
# 1216          RFn         TA         TA
# 1217          Unf         TA         TA
# 1218          RFn         TA         TA
# 1219          Unf         TA         TA
# 1220          Unf         TA         TA
# 1221          Unf         TA         TA
# 1222          Unf         TA         TA
# 1223          Unf         TA         TA
# 1224          Unf         TA         TA
# 1225          Fin         TA         TA
# 1226          RFn         TA         TA
# 1227          Fin         TA         TA
# 1228          Unf         TA         TA
# 1229          Fin         TA         TA
# 1230          Unf         TA         TA
# 1231          RFn         TA         TA
# 1232          Unf         TA         TA
# 1233          Unf         TA         TA
# 1234          RFn         TA         TA
# 1235          Unf         TA         TA
# 1236          Unf         Fa         Fa
# 1237          RFn         TA         TA
# 1238          Fin         TA         TA
# 1239          Unf         TA         TA
# 1240          RFn         TA         TA
# 1241          RFn         TA         TA
# 1242          RFn         TA         TA
# 1243          RFn         TA         TA
# 1245          Unf         TA         TA
# 1246          Fin         TA         TA
# 1247          RFn         TA         TA
# 1248          Unf         TA         TA
# 1249          Unf         Fa         Fa
# 1250          Unf         TA         TA
# 1251          Fin         TA         TA
# 1252          RFn         TA         TA
# 1253          RFn         TA         TA
# 1254          RFn         TA         TA
# 1255          Fin         TA         TA
# 1256          Unf         TA         TA
# 1257          Fin         TA         TA
# 1258          Unf         TA         TA
# 1259          Fin         TA         TA
# 1260          Unf         TA         TA
# 1261          Fin         TA         TA
# 1262          Unf         TA         TA
# 1263          Unf         TA         TA
# 1264          Unf         TA         TA
# 1265          Fin         TA         TA
# 1266          Unf         TA         TA
# 1267          Unf         TA         TA
# 1268          Fin         TA         TA
# 1269          Unf         TA         TA
# 1270          Unf         TA         TA
# 1271          Fin         TA         TA
# 1272          RFn         TA         TA
# 1273          Unf         TA         TA
# 1274          RFn         TA         TA
# 1275          Unf         TA         TA
# 1276          Unf         TA         Fa
# 1277          Unf         TA         TA
# 1278          RFn         TA         TA
# 1280          RFn         TA         TA
# 1281          RFn         TA         TA
# 1282          Fin         Gd         Gd
# 1283          Unf         TA         TA
# 1284          Unf         TA         TA
# 1285          Unf         TA         TA
# 1286          Unf         TA         TA
# 1287          Unf         TA         TA
# 1288          Unf         TA         TA
# 1289          Fin         TA         TA
# 1290          Fin         TA         TA
# 1291          RFn         TA         TA
# 1292          Unf         TA         TA
# 1293          RFn         TA         TA
# 1294          RFn         TA         TA
# 1295          Unf         TA         TA
# 1296          RFn         TA         TA
# 1297          RFn         TA         TA
# 1298          Fin         TA         TA
# 1299          Fin         TA         TA
# 1300          RFn         TA         TA
# 1301          Fin         TA         TA
# 1302          Unf         TA         TA
# 1303          RFn         TA         TA
# 1304          RFn         TA         TA
# 1305          Unf         TA         TA
# 1306          Fin         TA         TA
# 1307          RFn         TA         TA
# 1308          Unf         TA         TA
# 1309          Unf         TA         TA
# 1310          RFn         TA         TA
# 1311          Fin         TA         TA
# 1312          RFn         TA         TA
# 1313          RFn         Gd         Gd
# 1314          Fin         TA         TA
# 1315          Unf         TA         TA
# 1316          Unf         TA         TA
# 1317          RFn         TA         TA
# 1318          RFn         TA         TA
# 1319          RFn         TA         TA
# 1320          Unf         TA         TA
# 1321          RFn         TA         TA
# 1322          Unf         TA         Fa
# 1323          RFn         TA         TA
# 1324          Unf         TA         TA
# 1325          RFn         TA         TA
# 1326          Unf         TA         TA
# 1327          Unf         TA         TA
# 1328          Unf         TA         TA
# 1329          Unf         Fa         TA
# 1330          Fin         TA         TA
# 1331          RFn         TA         TA
# 1332          Unf         TA         TA
# 1333          Unf         Fa         Fa
# 1334          Unf         TA         TA
# 1335          Unf         TA         TA
# 1336          RFn         TA         TA
# 1337          Unf         TA         TA
# 1338          Unf         TA         TA
# 1339          RFn         TA         TA
# 1340          RFn         TA         TA
# 1341          Unf         TA         TA
# 1342          Unf         TA         TA
# 1343          RFn         TA         TA
# 1344          Unf         Fa         Fa
# 1345          Fin         TA         TA
# 1346          Unf         TA         TA
# 1347          RFn         Gd         TA
# 1348          Fin         TA         TA
# 1349          RFn         TA         TA
# 1350          Unf         TA         TA
# 1351          Unf         TA         TA
# 1352          Fin         TA         TA
# 1353          Unf         TA         TA
# 1354          Fin         TA         TA
# 1355          RFn         TA         TA
# 1356          RFn         TA         TA
# 1357          RFn         TA         TA
# 1358          Fin         TA         TA
# 1359          Unf         TA         TA
# 1360          Fin         TA         TA
# 1361          RFn         TA         TA
# 1362          Fin         TA         TA
# 1363          Unf         TA         TA
# 1364          Fin         TA         TA
# 1365          RFn         TA         TA
# 1366          RFn         TA         TA
# 1367          RFn         TA         TA
# 1368          RFn         TA         TA
# 1369          Fin         TA         TA
# 1370          Fin         TA         TA
# 1371          Fin         TA         TA
# 1372          RFn         TA         TA
# 1373          RFn         TA         TA
# 1374          RFn         TA         TA
# 1375          Fin         TA         TA
# 1376          Fin         TA         TA
# 1377          Unf         Fa         TA
# 1378          Unf         TA         TA
# 1379          Unf         TA         TA
# 1381          Unf         TA         Fa
# 1382          Fin         TA         TA
# 1383          Unf         TA         TA
# 1384          Unf         TA         TA
# 1385          Unf         TA         TA
# 1386          Unf         TA         TA
# 1387          RFn         TA         TA
# 1388          Unf         TA         TA
# 1389          Fin         TA         TA
# 1390          Unf         TA         TA
# 1391          RFn         TA         TA
# 1392          Unf         TA         TA
# 1393          RFn         TA         TA
# 1394          Unf         Gd         TA
# 1395          Fin         TA         TA
# 1396          Fin         TA         TA
# 1397          Unf         TA         TA
# 1398          Unf         Fa         Fa
# 1399          Unf         TA         TA
# 1400          Unf         Fa         TA
# 1401          RFn         TA         TA
# 1402          Fin         TA         TA
# 1403          RFn         TA         TA
# 1404          Unf         TA         TA
# 1405          Unf         TA         TA
# 1406          Fin         TA         TA
# 1407          Unf         TA         TA
# 1408          Unf         TA         TA
# 1409          Unf         TA         TA
# 1410          Fin         TA         TA
# 1411          RFn         TA         TA
# 1412          Unf         TA         TA
# 1413          Unf         TA         TA
# 1414          Fin         TA         TA
# 1415          Unf         TA         TA
# 1416          RFn         TA         TA
# 1417          Unf         TA         TA
# 1418          Fin         TA         TA
# 1419          Unf         TA         TA
# 1420          RFn         TA         TA
# 1421          RFn         TA         TA
# 1422          RFn         TA         TA
# 1423          Fin         TA         TA
# 1424          Unf         Gd         Gd
# 1425          Unf         TA         TA
# 1426          Unf         TA         TA
# 1427          RFn         TA         TA
# 1428          Unf         TA         TA
# 1429          Unf         TA         TA
# 1430          Fin         TA         TA
# 1431          Fin         TA         TA
# 1432          RFn         TA         TA
# 1433          Unf         Fa         Fa
# 1434          Fin         TA         TA
# 1435          RFn         TA         TA
# 1436          RFn         TA         TA
# 1437          Unf         TA         TA
# 1438          Fin         TA         TA
# 1439          Unf         TA         TA
# 1440          RFn         TA         TA
# 1441          Fin         TA         TA
# 1442          RFn         TA         TA
# 1443          Fin         TA         TA
# 1444          Unf         Fa         Po
# 1445          RFn         TA         TA
# 1446          Unf         TA         TA
# 1447          Unf         TA         TA
# 1448          RFn         TA         TA
# 1449          Unf         Fa         TA
# 1450          Unf         TA         TA
# 1451          Unf         TA         TA
# 1452          Fin         TA         TA
# 1453          Fin         TA         TA
# 1454          Unf         TA         TA
# 1455          RFn         TA         TA
# 1456          RFn         TA         TA
# 1457          Unf         TA         TA
# 1458          RFn         TA         TA
# 1459          Unf         TA         TA
# 1460          Fin         TA         TA

# %%
print(df.shape)
# Out:
# (1451, 74)

# %%
# Select only numerical columns for the correlation matrix
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
corr = numerical_df.corr()

# Plot the heatmap
plt.figure(figsize=(25, 25))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Simple Linear Regression

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='OverallQual',y='SalePrice',data=df,color = 'b')
sns.regplot(x='OverallQual',y='SalePrice',data=df ,scatter=False,color='r')
plt.title('Linear regression SalePrice')
plt.show()

# %%
x = df[['OverallQual']]
y = df['SalePrice']

# %%
# %pip install scikit-learn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score  # metrices that make evaluation to the model

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,shuffle=True,random_state=42)
x_train , x_val , y_train , y_val = train_test_split(x_train,y_train,test_size=0.125,shuffle=True,random_state=42)

# %%
print(f'x train shape:{x_train.shape}')
print(f'y train shape:{y_train.shape}')
print(f'x test shape:{x_test.shape}')
print(f'y test shape:{y_test.shape}')
# Out:
# x train shape:(1015, 1)
# y train shape:(1015,)
# x test shape:(291, 1)
# y test shape:(291,)

# %%
# load the model
lr_model = LinearRegression()

# %%
# train the model
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(x_train, y_train) # r2_score, evaluates model performance
# Out:
# 0.6063344482513054

# %%
lr_model.score(x_val, y_val) # if the output of previous cell is much larger than the output of this cell then there is overfitting
# Out:
# 0.6733577211789201

# %%
y_pred = lr_model.predict(x_test)

# %%
# evaluation
# R squared error, the important one
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.6651770843558391
# Mean Absolute Error :  30732.874685609804
# Mean Squared Error :  1867997026.867367

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Sale Prices")
plt.ylabel("Predicted Sale Prices")
plt.title("Actual Sale Price vs Predicted Sale Price")
plt.show()
# it should be positive linear relation

# %% [markdown]
# Multiple Linear Regression

# %%
# LinearRegression model requires all input features (x) and target variables (y) to be numeric. So we use one hot encoding for datasets with small no. of columns, and Label encoding with datasets with large no. of columns
from sklearn.preprocessing import LabelEncoder

non_numeric_columns = df.select_dtypes(include=['object', 'category']).columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# %%
x = df.drop(['SalePrice'], axis=1)
y = df['SalePrice']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,shuffle=True,random_state=42)
x_train , x_val , y_train , y_val = train_test_split(x_train,y_train,test_size=0.125,shuffle=True,random_state=42)

# %%
print(f'x train shape:{x_train.shape}')
print(f'y train shape:{y_train.shape}')
print(f'x test shape:{x_test.shape}')
print(f'y test shape:{y_test.shape}')
# Out:
# x train shape:(1015, 73)
# y train shape:(1015,)
# x test shape:(291, 73)
# y test shape:(291,)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(x_train, y_train)
# Out:
# 0.8354522392463608

# %%
lr_model.score(x_val, y_val)
# Out:
# 0.8835564454282555

# %%
y_pred = lr_model.predict(x_test)

# %%
# R squared error
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.8578341004631875
# Mean Absolute Error :  20218.39054019331
# Mean Squared Error :  793152037.2366775

# %%
# or by using Standardization, an optional processing step
scaler = StandardScaler()

# standardizing the features
x_train_Scaled = scaler.fit_transform(x_train)
x_test_Scaled  = scaler.transform(x_test)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(x_train_Scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(x_test_Scaled)

# %%
# R squared error
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.8573544842773642
# Mean Absolute Error :  20226.338423455894
# Mean Squared Error :  795827844.5583836

# %% [markdown]
# Lasso Regression (Linear Regression), decreases overfitting if exists

# %%
from sklearn.linear_model import Lasso , Ridge , LinearRegression
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# with one feature

# %%
x = df[['OverallQual']]
y = df['SalePrice']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,shuffle=True,random_state=42)
x_train , x_val , y_train , y_val = train_test_split(x_train,y_train,test_size=0.125,shuffle=True,random_state=42)

# %%
print(f'x train shape:{x_train.shape}')
print(f'y train shape:{y_train.shape}')
print(f'x test shape:{x_test.shape}')
print(f'y test shape:{y_test.shape}')
# Out:
# x train shape:(1015, 1)
# y train shape:(1015,)
# x test shape:(291, 1)
# y test shape:(291,)

# %%
lasso_model = Lasso()

# %%
lasso_model.fit(x_train, y_train)
# Out:
# Lasso()

# %%
lasso_model.score(x_train, y_train)
# Out:
# 0.6063344481698554

# %%
lasso_model.score(x_val, y_val)
# Out:
# 0.673357170019486

# %%
y_pred = lasso_model.predict(x_test)

# %%
# R squared error, the important one
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.6651769282650057
# Mean Absolute Error :  30732.85789067079
# Mean Squared Error :  1867997897.7074413

# %% [markdown]
# with multiple features

# %%
# LinearRegression model requires all input features (x) and target variables (y) to be numeric. So we use one hot encoding for datasets with small no. of columns, and Label encoding with datasets with large no. of columns
from sklearn.preprocessing import LabelEncoder

non_numeric_columns = df.select_dtypes(include=['object', 'category']).columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# %%
x = df.drop(['SalePrice'], axis=1)
y = df['SalePrice']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,shuffle=True,random_state=42)
x_train , x_val , y_train , y_val = train_test_split(x_train,y_train,test_size=0.125,shuffle=True,random_state=42)

# %%
print(f'x train shape:{x_train.shape}')
print(f'y train shape:{y_train.shape}')
print(f'x test shape:{x_test.shape}')
print(f'y test shape:{y_test.shape}')
# Out:
# x train shape:(1015, 73)
# y train shape:(1015,)
# x test shape:(291, 73)
# y test shape:(291,)

# %%
lasso_model = Lasso()

# %%
lasso_model.fit(x_train, y_train)
# Out:
# c:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.301e+10, tolerance: 6.512e+08
#   model = cd_fast.enet_coordinate_descent(
# Lasso()

# %%
lasso_model.score(x_train, y_train)
# Out:
# 0.835451948448408

# %%
lasso_model.score(x_val, y_val)
# Out:
# 0.8835750523773164

# %%
y_pred = lasso_model.predict(x_test)

# %%
# R squared error, the important one
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.8578339465365714
# Mean Absolute Error :  20213.551921504295
# Mean Squared Error :  793152896.0024549

# %%
# or by using Standardization
scaler = StandardScaler()

# standardizing the features
x_train_Scaled = scaler.fit_transform(x_train)
x_test_Scaled  = scaler.transform(x_test)

# %%
lasso_model = Lasso()

# %%
lasso_model.fit(x_train_Scaled, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso_model.predict(x_test_Scaled)

# %%
# R squared error, the important one
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.8578553938109339
# Mean Absolute Error :  20215.11567812133
# Mean Squared Error :  793033240.3789247

# %% [markdown]
# Ridge Regression (Linear Regression)

# %% [markdown]
# with one feature

# %%
x = df[['OverallQual']]
y = df['SalePrice']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,shuffle=True,random_state=42)
x_train , x_val , y_train , y_val = train_test_split(x_train,y_train,test_size=0.125,shuffle=True,random_state=42)

# %%
print(f'x train shape:{x_train.shape}')
print(f'y train shape:{y_train.shape}')
print(f'x test shape:{x_test.shape}')
print(f'y test shape:{y_test.shape}')
# Out:
# x train shape:(1015, 1)
# y train shape:(1015,)
# x test shape:(291, 1)
# y test shape:(291,)

# %%
ridge_model = Ridge()

# %%
ridge_model.fit(x_train, y_train)
# Out:
# Ridge()

# %%
ridge_model.score(x_train, y_train)
# Out:
# 0.6063342877047262

# %%
ridge_model.score(x_val, y_val)
# Out:
# 0.6733330880891384

# %%
y_pred = ridge_model.predict(x_test)

# %%
# R squared error, the important one
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.6651699856973221
# Mean Absolute Error :  30732.408035135166
# Mean Squared Error :  1868036630.7068446

# %% [markdown]
# with multiple features

# %%
# LinearRegression model requires all input features (x) and target variables (y) to be numeric. So we use one hot encoding for datasets with small no. of columns, and Label encoding with datasets with large no. of columns
from sklearn.preprocessing import LabelEncoder

non_numeric_columns = df.select_dtypes(include=['object', 'category']).columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# %%
x = df.drop(['SalePrice'], axis=1)
y = df['SalePrice']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,shuffle=True,random_state=42)
x_train , x_val , y_train , y_val = train_test_split(x_train,y_train,test_size=0.125,shuffle=True,random_state=42)

# %%
print(f'x train shape:{x_train.shape}')
print(f'y train shape:{y_train.shape}')
print(f'x test shape:{x_test.shape}')
print(f'y test shape:{y_test.shape}')
# Out:
# x train shape:(1015, 73)
# y train shape:(1015,)
# x test shape:(291, 73)
# y test shape:(291,)

# %%
ridge_model = Ridge()

# %%
ridge_model.fit(x_train, y_train)
# Out:
# Ridge()

# %%
ridge_model.score(x_train, y_train)
# Out:
# 0.8353404089034455

# %%
ridge_model.score(x_val, y_val)
# Out:
# 0.8836247175415414

# %%
y_pred = ridge_model.predict(x_test)

# %%
# R squared error, the important one
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.857705828017071
# Mean Absolute Error :  20191.938171543683
# Mean Squared Error :  793867676.8681941

# %%
# or by using Standardization
scaler = StandardScaler()

# standardizing the features
x_train_Scaled = scaler.fit_transform(x_train)
x_test_Scaled  = scaler.transform(x_test)

# %%
ridge_model = Ridge()

# %%
ridge_model.fit(x_train_Scaled, y_train)
# Out:
# Ridge()

# %%
y_pred = ridge_model.predict(x_test_Scaled)

# %%
# R squared error, the important one
score_1 = r2_score(y_test, y_pred)

# Mean Absolute Error
score_2 = mean_absolute_error(y_test, y_pred)

#mean squared error

score_3 = mean_squared_error(y_test, y_pred)

print('R2 Score : ', score_1)
print('Mean Absolute Error : ', score_2)
print('Mean Squared Error : ', score_3)
# Out:
# R2 Score :  0.85792479675456
# Mean Absolute Error :  20203.80874495398
# Mean Squared Error :  792646037.2148285

# %% [markdown]
# The best models are the models with the highest r2 score which is equal to 0.85:
# Multiple linear regression with, or without standardization
# Lasso regression with multiple features with, or without standardization
# Ridge regression with multiple features with, or without standardization
